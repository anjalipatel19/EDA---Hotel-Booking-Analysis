# %% [markdown]
# # **Project Name**    - **Hotel Booking Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 - Anjali Patel**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The hotel industry is known for its lucrative yet highly volatile nature. Success in this sector depends on numerous factors, including the type of hotel, seasonal variations in business, customer segments, various booking methods, amenities, and services. While the hotel industry experienced significant profitability over the past few decades, it also faced a severe setback due to the global pandemic. This downturn prompted many entrepreneurs and business leaders to recognize the importance of strategic decision-making and data analysis to navigate the market effectively and gain a competitive edge.
#
# This study employs principles of Exploratory Data Analysis (EDA) and feature engineering to explore the advantages of analyzing a dataset related to hotel bookings. The primary objective is to uncover insights that can help expand the customer base. A secondary aim is to assist customers in choosing the best times to travel while taking advantage of lower accommodation costs. The dataset provided contains booking information for two types of hotels and various related booking criteria.
#
# The approach begins with thorough data exploration and examination of the raw data. The next step involves data cleaning, which includes handling missing values, removing irrelevant columns and rows, converting date strings into DateTime format, and creating new feature columns to enhance decision support. The final step entails conducting a comprehensive data analysis on the cleaned dataset to understand the factors influencing hotel bookings. Additionally, data visualization is employed to illustrate these factors, aiding in the identification of booking, pricing, and other correlated trends. These insights can be valuable for making informed high-level business predictions.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# This data set contains booking information for a city hotel and a resort hotel, and includes all the information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data.
#
# Explore and analyze the data to discover important factors that govern the bookings.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The dataset contains booking information for two different hotels. One is the City Hotel and another is the Resort Hotel along with information on various booking criteria such as booking season, time of booking, length of stay, number of adults, children and babies, parking spaces, pricing data, market segment and many more.
#
# 1.   Primary objective is to explore and inspect the dataset; and discover important features using Exploratory Data Analysis that can govern bookings and help hotels penetrate deep into market, thereby attracting more customers. Analyze booking and pricing trends to draw out insights to make intelligent business decision.
# 2.   Secondary objective is help the customers in deciding best period to visit places while availing low accommodation cost benefits.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from datetime import datetime

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
# Mounting Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# csv file location
csv_file = ('/content/drive/MyDrive/EDA - Hotel Booking Analysis/Hotel Bookings.csv')

# Reading the data set
data_set = pd.read_csv(csv_file)

# Creating a copy of data set
data = data_set.copy()

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
# Checking the first 5 rows of data
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# Checking the bottom 5 rows of the data
data.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f'We have {data.shape[0]} of rows and {data.shape[1]} columns.')
# Out:
# We have 119390 of rows and 32 columns.

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
# Inspecting each columns and its datatypes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
data.duplicated().value_counts()
# True means duplicate rows
# Out:
# False    87396
# True     31994
# dtype: int64

# %%
# Visualizing it through the Count Plot
plt.figure(figsize=(10,8))
sns.countplot(x=data.duplicated())
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # **This plot has made us clear that it has 31994 duplicate rows in our data. So we will drop this duplicate rows from our data.**

# %%
# Dropping the duplicate rows
data = data.drop_duplicates()

# %%
# Dataset reduced
data.shape
# Out:
# (87396, 32)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
null_df = pd.DataFrame(data.isnull().sum().sort_values(ascending = False)[:6], columns=['Null values'])
null_df['Null Percentage'] = null_df['Null values'] / data.shape[0] * 100
null_df
# Out:
#                     Null values  Null Percentage
# company                   82137        93.982562
# agent                     12193        13.951439
# country                     452         0.517186
# children                      4         0.004577
# reserved_room_type            0         0.000000
# assigned_room_type            0         0.000000

# %%
# Visualizing the missing values through heatmap
plt.figure(figsize=(25, 10))
sns.heatmap(data.isnull(), cbar=True, yticklabels=False,cmap='inferno')
plt.xlabel("Name of Columns")
plt.title("Places of missing values in column")
# Out:
# Text(0.5, 1.0, 'Places of missing values in column')

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# We have null values in 4 columns and will replace them all by other values  they are :-
# 1.   Company - Will dop the column beacuse it almost contains all null data.
# 2.   Agent - Will place 0 in the null values.
# 3.   Country - Will place NotEntered in the null values.
# 4.   Children - Will place 0 in the null values.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print(list(data.columns))
# Out:
# ['hotel', 'is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent', 'company', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', 'reservation_status_date']

# %%
# Dataset Describe
data.describe(include = 'all')
# Out:
#              hotel   is_canceled     lead_time  arrival_date_year  \
# count        87396  87396.000000  87396.000000       87396.000000
# unique           2           NaN           NaN                NaN
# top     City Hotel           NaN           NaN                NaN
# freq         53428           NaN           NaN                NaN
# mean           NaN      0.274898     79.891368        2016.210296
# std            NaN      0.446466     86.052325           0.686102
# min            NaN      0.000000      0.000000        2015.000000
# 25%            NaN      0.000000     11.000000        2016.000000
# 50%            NaN      0.000000     49.000000        2016.000000
# 75%            NaN      1.000000    125.000000        2017.000000
# max            NaN      1.000000    737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count               87396              87396.000000
# unique                 12                       NaN
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1. **hotel** : Hotel(Resort Hotel or City Hotel)
#
# 2. **is_canceled** : Value indicating if the booking was canceled (1) or not (0)
#
# 3. **lead_time** : Number of days that elapsed between the entering date of the booking into the PMS and the arrival date
#
# 4. **arrival_date_year** : Year of arrival date
#
# 5. **arrival_date_month** : Month of arrival date
#
# 6. **arrival_date_week_number** : Week number of year for arrival date
#
# 7. **arrival_date_day_of_month** : Day of arrival date
#
# 8. **stays_in_weekend_nights** : Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
#
# 9. **stays_in_week_nights** : Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel
#
# 10. **adults** : Number of adults
#
# 11. **children** : Number of children
#
# 12. **babies** : Number of babies
#
# 13. **meal** : Type of meal booked.
#
# 14. **country** : Country of origin.
#
# 15. **market_segment** : Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# 16. **distribution_channel** : Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# 17. **is_repeated_guest** : Value indicating if the booking name was from a repeated guest (1) or not (0)
#
# 18. **previous_cancellations** : Number of previous bookings that were cancelled by the customer prior to the current booking
#
# 19. **previous_bookings_not_canceled** : Number of previous bookings not cancelled by the customer prior to the current booking
#
# 20. **reserved_room_type** : Code of room type reserved. Code is presented instead of designation for anonymity reasons.
#
# 21. **assigned_room_type** : Code for the type of room assigned to the booking.
#
# 22. **booking_changes** : Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation
#
# 23. **deposit_type** : Indication on if the customer made a deposit to guarantee the booking.
#
# 24. **agent** : ID of the travel agency that made the booking
#
# 25. **company** : ID of the company/entity that made the booking or responsible for paying the booking.
#
# 26. **days_in_waiting_list** : Number of days the booking was in the waiting list before it was confirmed to the customer
#
# 27. **customer_type** : Type of booking, assuming one of four categories
#
#
# 28. **adr** : Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights
#
# 29. **required_car_parking_spaces** : Number of car parking spaces required by the customer
#
# 30. **total_of_special_requests** : Number of special requests made by the customer (e.g. twin bed or high floor)
#
# 31. **reservation_status** : Reservation last status, assuming one of three categories
# * Canceled – booking was canceled by the customer
# * Check-Out – customer has checked in but already departed
# * No-Show – customer did not check-in and did inform the hotel of the reason why
#
#
#
#
#
# 32. **reservation_status_date** : Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
#Removing the datetime datatype and unique country data
unique_values=list(set(data.drop(columns=['reservation_status_date','country','arrival_date_month','arrival_date_day_of_month', 'arrival_date_year']).columns)- set(data.describe()))

#Runing the forloop to know the unique values for data analysis
for col in unique_values:
  print(f'Unique values in column {col} are:, {(data[col].unique())}')
# Out:
# Unique values in column meal are:, ['BB' 'FB' 'HB' 'SC' 'Undefined']
# Unique values in column customer_type are:, ['Transient' 'Contract' 'Transient-Party' 'Group']
# Unique values in column deposit_type are:, ['No Deposit' 'Refundable' 'Non Refund']
# Unique values in column market_segment are:, ['Direct' 'Corporate' 'Online TA' 'Offline TA/TO' 'Complementary' 'Groups'
#  'Undefined' 'Aviation']
# Unique values in column reserved_room_type are:, ['C' 'A' 'D' 'E' 'G' 'F' 'H' 'L' 'P' 'B']
# Unique values in column distribution_channel are:, ['Direct' 'Corporate' 'TA/TO' 'Undefined' 'GDS']
# Unique values in column assigned_room_type are:, ['C' 'A' 'D' 'E' 'G' 'F' 'I' 'B' 'H' 'P' 'L' 'K']
# Unique values in column hotel are:, ['Resort Hotel' 'City Hotel']
# Unique values in column reservation_status are:, ['Check-Out' 'Canceled' 'No-Show']

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# Placing null values in Agent column with 0
data["agent"].fillna(0,inplace=True)

# Placing null values in children with 0
data["children"].fillna(0,inplace=True)

# Placing null values in Country with 'NotEntered'
data["country"].fillna('NotEntered',inplace = True)

# %%
# Droping company column because it contains all null data
data.drop(['company'], axis=1, inplace=True)

# Droping rows where there is no data in adults, children, babies together
no_guest=data[data['adults']+data['babies']+data['children']==0]
data.drop(no_guest.index, inplace=True)

# %%
# Checking the null values
data.isna().sum().sort_values(ascending=False)[:5]
# Out:
# hotel                          0
# is_repeated_guest              0
# reservation_status             0
# total_of_special_requests      0
# required_car_parking_spaces    0
# dtype: int64

# %%
# Parsing reservation_status date into datetime
data['reservation_status_date'] = pd.to_datetime(data['reservation_status_date'], format = '%Y-%m-%d')

# %%
# Parsing arrival_date_month into datetime and adding a new column with parsed month number
data['arrival_month'] = data['arrival_date_month'].apply(lambda x : datetime.strptime(x,'%B'))
data['arrival_month'] = data['arrival_month'].apply(lambda x : x.month)           #Will be used for sorting columns months wise

# %%
# Adding new column "total_people" by adding columns values of 'adults', 'children' and 'babies'
data['total_people'] = data['adults'] + data['children'] + data ['babies']

# Adding new column 'total_stay' by adding columns values of 'stays_in_weekend_nights' and 'stays_in_week_nights'
data['total_stay'] = data ['stays_in_weekend_nights'] + data ['stays_in_week_nights']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87230 entries, 0 to 119389
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87230 non-null  object
#  1   is_canceled                     87230 non-null  int64
#  2   lead_time                       87230 non-null  int64
#  3   arrival_date_year               87230 non-null  int64
#  4   arrival_date_month              87230 non-null  object
#  5   arrival_date_week_number        87230 non-null  int64
#  6   arrival_date_day_of_month       87230 non-null  int64
#  7   stays_in_weekend_nights         87230 non-null  int64
#  8   stays_in_week_nights            87230 non-null  int64
#  9   adults                          87230 non-null  int64
#  10  children                        87230 non-null  float64
#  11  babies                          87230 non-null  int64
# ...

# %%
#Checking of new columns
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
#Final size of dataset post cleaning
data.shape
# Out:
# (87230, 34)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I have added two new columns here named total people and total stay. In total people I have combined values of adults, children and babies together. In total stay I have combined values of stays in weekend nights and stays in week nights.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# # **Which type of Hotel is mostly preferred by the guests ?**

# %%
# Chart - 1 visualization code
# Fetching unique hotel count
booking_df = data['hotel'].value_counts()
booking_df
# Out:
# City Hotel      53274
# Resort Hotel    33956
# Name: hotel, dtype: int64

# %%
# Plotting pie chart of unique Hotel booking %
x_axis = booking_df.plot.pie(figsize=(12,8),fontsize=20, autopct='%5.1f%%', explode=[0.05,0.05])

x_axis.set_title('Booking percentage in each type of Hotel',fontsize=20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts typically show relative proportions of different categories in a data set.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Majority of the guest prefer City Hotel over Resort Hotel and 2/3rd of total guest prefer City Hotel

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, because it will help business owners to decide on which type of hotel to invest their money so they can gain maximum profits.

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# # **From which country most guest are coming ?**

# %%
# Chart - 2 visualization code
# Counting the guests from various countries
data_country = data['country'].value_counts().reset_index().rename(columns={'index': 'country','country': 'count of guests'})[:10]

# Visualizing by plotting the graph
plt.figure(figsize=(20,8))
sns.barplot(x=data_country['country'],y=data_country['count of guests'])
plt.xlabel('Country',fontsize=20)
plt.ylabel('Number of guests',fontsize=20)
plt.title("Number of guests from diffrent types of Countries",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Number of guests from diffrent types of Countries')

# %% [markdown]
# **Abbreviations for all types of countries**
#
# 1.   PRT - Portugal
# 2.   GBR - United Kingdom
# 3.   FRA - France
# 4.   ESP - Spain
# 5.   DEU - Germany
# 6.   ITA - Itlay
# 7.   IRL - Ireland
# 8.   BEL - Belgium
# 9.   BRA - Brazil
# 10.  NLD - Netherlands

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart shows catergorical data as rectangular bars with the height of bars proportional to the value they represent. It is often used to compare between values of different categories in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the bar chart, its evident that most of the guest are visiting these City hotels and Resort hotels are from Portugal and other European countries namely Britain, France, Spain and Germany.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, because now the hotel owners will understand the reason as why majority of the customers are from Portugal. The countries where the numbers are low, will think that how the other hotels are been managed. Since Portugal is occupying the largest in the chart, the business owner may now do marketing by applying the 80:20 rule to maximize their profits.

# %% [markdown]
# #### Chart - 3

# %% [markdown]
# # **Which is the most preferred type of rooms by the guests ?**

# %%
# Chart - 3 visualization code
# Setting plotsize
plt.figure(figsize=(20,10))

# Plotting
sns.countplot(x=data['assigned_room_type'],order=data['assigned_room_type'].value_counts().index)
#  setting xlabel for the plot
plt.xlabel('Room Type',fontsize=20)
# setting y label for the plot
plt.ylabel('Count of Room Type',fontsize=20)
# setting title for the plot
plt.title("Most preferred Room type",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Most preferred Room type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart because it is often used to compare between values of different categories in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most demanded room type is A then other is D and E.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# They should increase the room type A as it is in full demand.

# %% [markdown]
# #### Chart - 4

# %% [markdown]
# # **Which type of food is mostly preferred by the guests ?**

# %%
# Chart - 4 visualization code

# Plotting the chart of preferred meal type
plt.figure(figsize=(20,10))
sns.countplot(x=data['meal'])
plt.xlabel('Meal Type',fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.title("Preferred Meal Type",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Preferred Meal Type')

# %% [markdown]
# Types of meal offered in hotels are:
# * BB - (Bed and Breakfast)
# * HB- (Half Board)
# * FB- (Full Board)
# * SC- (Self Catering)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart because it is often used to compare between values of different categories in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most preferred meal type by the guests is BB(Bed and Breakfast). But the HB- (Half Board) and SC- (Self Catering) both are equally preferred by the guests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, with this the hotel owner may be able to switch to dynamic pricing models for their meal plans. For those meal plan with the highest demand which is Bed and Breakfast can be charged little bit higher with more added features, while those with the less demand can be charged a bit lower, to attract the customers to avail that meal type.

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# # **Which year had the highest bookings till now ?**

# %%
# Chart - 5 visualization code
# Setting the plot size
plt.figure(figsize=(10,5))

# Plotting with countplot
list1=['hotel', 'arrival_date_year', 'arrival_date_month','arrival_date_day_of_month']
arrival_overview = data[list1]
sns.countplot(data = arrival_overview, x = 'arrival_date_year', hue = 'hotel').set_title('Customer arrived in year',fontsize=20)
plt.xlabel('Years', fontsize = 15)
plt.ylabel('Number of bookings',fontsize = 15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart because it is often used to compare between values of different categories in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see that 2016 was the year where number of hotel booking was highest for both City and Resort Hotel by the total bookings in 2017 and 2015. The City Hotel had the highest booking then Resort Hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, hotel owners should divert more of their resources in the City hotels to maximise their profits, even can have Resort hotel also both if they can afford.

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# # **In which month most of the bookings have happened ?**

# %%
# Chart - 6 visualization code
# grouping by arrival_date_month and taking the hotel count
bookings_by_months_df = data.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns={'hotel':"Counts"})

# Creating list of months in order
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# creating df which will map the order of above months list without changing its values.
bookings_by_months_df['arrival_date_month'] = pd.Categorical(bookings_by_months_df['arrival_date_month'],categories=months,ordered=True)

# sorting by arrival_date_month
bookings_by_months_df = bookings_by_months_df.sort_values('arrival_date_month')

bookings_by_months_df
# Out:
#    arrival_date_month  Counts
# 4             January    4685
# 3            February    6083
# 7               March    7489
# 0               April    7900
# 8                 May    8344
# 6                June    7756
# 5                July   10043
# 1              August   11242
# 11          September    6682
# 10            October    6921
# 9            November    4973
# 2            December    5112

# %%
# Setting plot size
plt.figure(figsize=(20,10))

# Plotting lineplot on x-months & y-booking counts
sns.lineplot(x=bookings_by_months_df['arrival_date_month'],y=bookings_by_months_df['Counts'])

# Setting title for the plot
plt.title('Number of bookings across each month',fontsize=25)
# Setting x label
plt.xlabel('Month',fontsize=20)
# Setting y label
plt.ylabel('Number of bookings',fontsize=20)
# Out:
# Text(0, 0.5, 'Number of bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line charts are used to represent the relation between two data X and Y on a different axis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The peak visiting season is from mid June to August because of summer breaks in Europe and the off season is from November to February because of cold weather throughout Europe

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights can be used by hotel owners to apply dynamic pricing to their packages. In peak seasons, price may be kept higher. For example, during summer holidays from June to September, prices may be kept higher, while during off season (Winter months) from November to February, price may be kept lower.

# %% [markdown]
# #### Chart - 7

# %% [markdown]
# # **Which distribution type of channel is mostly used for hotel bookings ?**

# %%
# Chart - 7 visualization code
# Creating labels
label = data['distribution_channel'].value_counts().index.tolist()

# Creating new df of distribution channel
distribution_channel_df= data['distribution_channel'].value_counts().reset_index().rename(columns={'index':"distribution_channel",'distribution_channel':'count'})

# Adding percentage columns to the distribution_channel_df
distribution_channel_df['percentage']=round(distribution_channel_df['count']*100/data.shape[0],1)

# Creating list of percentage
size=distribution_channel_df['percentage'].values.tolist()

# Plotting the pie chart
data['distribution_channel'].value_counts().plot.pie(explode=[0.05, 0.05,0.05,0.05,0.05], shadow=False, figsize=(20,10),fontsize=10,label=None)

# Setting legends with the percentage values
label = [f'{l}, {s}%' for l, s in zip(label, size)]
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=label)
plt.title(' Mostly Used Distribution Channel for Hotel Bookings ')
# Out:
# Text(0.5, 1.0, ' Mostly Used Distribution Channel for Hotel Bookings ')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts typically show relative proportions of different categories in a data set.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  We can see, Resort hotel and City hotel are getting most of bookings from travel agency and tour operators. May be in future they will be monopolize the entire booking channel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Hence hotel owners should promote more in different market segments to beat the monopoly condition. They may also find ways to develop a strong partnership with the TA/TO to increase their bookings count and help them make more profits by giving some discounts if you book through TA/TO website.

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# # **What is the percentage of cancellation ?**

# %%
# Chart - 8 visualization code

# Plotting the pie chart
data['is_canceled'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', shadow=True, figsize=(20,10),fontsize=20)
# Setting the title
plt.title("Cancellation and Non-Cancellation")
# Out:
# Text(0.5, 1.0, 'Cancellation and Non-Cancellation')

# %% [markdown]
# * 0 - Not Cancelled
# * 1 - Cancelled

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts typically show relative proportions of different categories in a data set.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 27.5 % of the bookings were cancelled, while 72.5% were not cancelled.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Hotel owners should try to find out why did the customers, who has booked earlier, went on to cancel the booking. By taking their feedback through voice call or email, companies may know the reason. Accordingly they may change their strategy to counter such scenarios in the future.

# %% [markdown]
# #### Chart - 9

# %% [markdown]
# # **Which Agent has made the most bookings ?**

# %%
# Chart - 9 visualization code
# Return highest bookings made by agents
highest_booking = data.groupby(['agent'])['agent'].agg({'count'}).reset_index().rename(columns={'count': "Most_Bookings" }).sort_values(by='Most_Bookings',ascending=False)

# As agent 0 was a NAN value, we replaced it with 0 which indicates no bookings. So decided to drop.
highest_booking.drop(highest_booking[highest_booking['agent']==0].index,inplace=True)

# Taking into consideration top 10 agents
topten_highest_booking = highest_booking[:10]

topten_highest_booking
# Out:
#      agent  Most_Bookings
# 9      9.0          28721
# 174  240.0          13028
# 14    14.0           3342
# 7      7.0           3294
# 183  250.0           2779
# 175  241.0           1644
# 27    28.0           1493
# 8      8.0           1383
# 1      1.0           1228
# 6      6.0           1117

# %%
# Plotting the graph
plt.figure(figsize=(20,10))
sns.barplot(x=topten_highest_booking['agent'],y=topten_highest_booking['Most_Bookings'],order=topten_highest_booking['agent'])
plt.xlabel('Agent No',fontsize=20)
plt.ylabel('Number of Bookings',fontsize=20)
plt.title("Most bookings made by the agent",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Most bookings made by the agent')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# A bar chart because it is often used to compare between values of different categories in the data.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the above insight, hotel owners may incentivise both the top two agents, while at the same time motivate others to make bookings also.

# %% [markdown]
# #### Chart - 10

# %% [markdown]
# # **What is the percentage of repeated guests ?**

# %%
# Chart - 10 visualization code
# Plotting a pie chart
data['is_repeated_guest'].value_counts().plot.pie(explode=(0.05,0.05),autopct='%1.1f%%',shadow=True,figsize=(15,10),fontsize=20)
# Creating the title
plt.title(" Percentage of repeated guests",fontsize=20)
# Out:
# Text(0.5, 1.0, ' Percentage of repeated guests')

# %% [markdown]
# *   0 - Not repeated guest
# *   1 - Repeated guest

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts typically show relative proportions of different categories in a data set.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Repeated guests are very few which only comprise of 3.9 %.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Hotel owners should take feedbacks from the guests and try to improve upon the services or provide something unique than their competitors.

# %% [markdown]
# #### Chart - 11

# %% [markdown]
# # **What is the optimal length of stay in both types of hotels ?**

# %%
# Chart - 11 visualization code
# Creating a not cancelled dataframe
not_cancelled_df = data[data['is_canceled'] == 0]
# Creating a hotel stay dataframe
hotel_stay_df1 = not_cancelled_df[not_cancelled_df['total_stay'] <= 15]  #Visualizing pattern till 15days stay

# %%
# Setting plot size and plotting barchart
plt.figure(figsize = (20,10))
sns.countplot(x = hotel_stay_df1['total_stay'], hue = hotel_stay_df1['hotel'])

# Adding the label of the chart
plt.title('Preferred stay length in each Hotel',fontsize=20)
plt.xlabel('Stay length in days', fontsize=20)
plt.ylabel("Count of tourist's stay", fontsize=20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart because it is often used to compare between values of different categories in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The guests prefer 1-4 days when staying in City Hotels. The guests prefer 1-4 days when staying in Resort Hotels as well, while 7 days stay is also a popular choice among guests for Resort hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, hotel owners may bring in more packages targeting the 1-4 days group. In case of Resort hotel, 7 days packages could be continued looking at their popularity among guests.

# %% [markdown]
# #### Chart - 12

# %% [markdown]
# # **Which distribution channel contributed more to ADR in order to increase the income ?**

# %%
# Chart - 12 visualization code
# Groupby distribution channel and hotel
barchart = data.groupby(['hotel','distribution_channel'])['adr'].count().unstack().transpose().fillna(0)
barchart.drop('Undefined',axis =0, inplace = True)

# %%
# Displaying the bar_chart DataFrame
barchart
# Out:
# hotel                 City Hotel  Resort Hotel
# distribution_channel
# Corporate                 2591.0        2471.0
# Direct                    6056.0        6898.0
# GDS                        181.0           0.0
# TA/TO                    44442.0       24586.0

# %%
# Plotting bar chart for distribution channel of both hotels by average daily rate
x1 = barchart.plot(kind = "barh",figsize=(20,10))
x1.legend(bbox_to_anchor=(1,1))

# Adding the label of the chart
x1.yaxis.set_label_text("Market segment", fontsize = 20)
x1.xaxis.set_label_text("Average daily Rate", fontsize = 20)
x1.set_title("Market segment wise ADR", fontsize = 20)

# Displaying the chart
plt.show()

# %% [markdown]
# * Corporate - These are corporate hotel booking companies which makes bookings
# possible.
# * GDS - A GDS is a worldwide conduit between travel bookers and suppliers, such as hotels and other accommodation providers. It communicates live products, price and availability data to travel agents and online booking engines, and allows for automated transactions.
# * Direct- The bookings which are directly made with the respective hotels.
# * TA/TO- The bookings which are made through  travel agents or tour operators.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart because it is often used to compare between values of different categories in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 'Direct' and 'TA/TO' channel has almost equally contributed in ADR in both type of hotels i.e. 'City Hotel' and 'Resort Hotel'. While 'TA/TO' dominates the chart in terms of total ADR. GDS has slightly contributed in adr in 'City Hotel' type. Corporate booking channel has also contributed to the ADR.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the hotel owners should tie up with TA/TO partners, to increase their market share.

# %% [markdown]
# #### Chart - 13

# %% [markdown]
# # **What is the reservation status from different distribution Channels ?**

# %%
# Chart - 13 visualization code
# Groupby Reservation Status and Distribution Channels for each Hotel
tbl1=data.groupby(['hotel','distribution_channel','reservation_status'], as_index=False)['is_canceled'].count().sort_values('is_canceled', ascending=False)
pivot=tbl1.pivot_table(values='is_canceled', index=['hotel','distribution_channel'],columns='reservation_status').transpose()
pivot.fillna(0, inplace=True)

# %%
# Plotting bar graph for different Reservation status by diiferent Distribution Channels
channel=pivot.plot(kind = 'bar',figsize=(20,10))
channel.legend(bbox_to_anchor=(1,1))

# Labeling the chart
channel.yaxis.set_label_text("Count of Reservation Status", fontsize = 15)
channel.xaxis.set_label_text("Reservation Status", fontsize = 15)
channel.set_title("Reservation status of different Distribution Channels", fontsize = 20)
plt.xticks(rotation = 0,fontsize = 12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart because it is often used to compare between values of different categories in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see that Bookings and Cancellations from both Hotels are more from Travel agency (TA/TO). The guest visiting both hotels, directly and via Corporate are less likely to cancel their booking. We can also notice a very small proportion of guest booking via Travel agency not showing up at Hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the hotel owners should communicate and discuss with the travel agents/ tour operators, various ways in which then can prevent such cancellations from happening.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Aggregation of guest's monthly bookings which were checked out
not_cancelled_df = data[data['is_canceled'] == 0]
checked_out = not_cancelled_df.groupby(['arrival_month'], as_index=False).agg({'is_canceled':'count',
                                                                     'adr':'mean',
                                                                     'total_stay':'sum',
                                                                     'required_car_parking_spaces':'sum',
                                                                     'is_repeated_guest':'sum'})

# Guest who cancelled their booking
cancelled_df = data.loc[data['reservation_status']=='Canceled',['arrival_month','reservation_status']]
cancelled_df.replace('Canceled',1, inplace=True)
cancelled = cancelled_df.groupby(['arrival_month'], as_index=False)['reservation_status'].sum()

# %%
# Merging Cancelled and Non-cancelled dataset based on Month
merge_df = pd.merge(checked_out,cancelled, how = 'inner', on = ['arrival_month'])
merge_df.rename(columns={'is_canceled':'Booking Count',
                         'adr':'Price',
                         'total_stay':'Total stay',
                         'reservation_status':'Cancellation',
                         'is_repeated_guest':'Repeated Customer',
                         'required_car_parking_spaces':'Parking Spaces'},inplace=True)

# %%
# Plotting correlation heatmap for different booking criteria
plt.figure(figsize=(20,10))
sns.heatmap(merge_df[['Booking Count','Price','Total stay','Cancellation','Repeated Customer','Parking Spaces']].corr(),vmin=-1,annot=True, annot_kws={"size":13})

plt.title('Co-relation of the columns', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15,rotation=0)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Correlation heatmaps was used to find potential relationships between variables and to understand the strength of these relationships.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is a high positive correlation between Booking and Pricing, Total Stay, Cancellations and Parking spaces, where as negative correlation with Repeated guests. The increase in Pricing leads to repeated Customers not visiting again. There is firm correlation between Parking space and Cancellation inferring that people are more likely to cancel their booking if Parking space is not available.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
# Finding the first 5 rows of merge_df Dataframe
merge_df.head()
# Out:
#    arrival_month  Booking Count       Price  Total stay  Parking Spaces  \
# 0              1           3648   67.294937       10179             485
# 1              2           4671   73.009336       13982             501
# 2              3           5660   78.069223       18379             585
# 3              4           5494   99.482392       18457             627
# 4              5           5902  106.901777       20127             602
#
#    Repeated Customer  Cancellation
# 0                370           968
# 1                350          1273
# 2                396          1714
# 3                252          2331
# 4                317          2340

# %%
# Plotting the pair plot chart
sns.pairplot(merge_df, kind = "reg")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Seaborn Pairplot allows us to plot pairwise relationships between variables within a dataset. This creates a nice visualisation and helps us to understand the data by summarising a large amount of data in single figures.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is a high positive correlation between Booking and Pricing, Total Stay, Cancellations and Parking spaces, where as negative correlation with Repeated guests. The increase in Pricing leads to repeated Customers not visiting again. There is firm correlation between Parking space and Cancellation infering that people are more likely to cancel their booking if Parking space is not available.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# I would suggest that the clients to make their price dynamic, introduce offers and packages to attract new customers. To retain the existing customers and ensure their repetition the clients must introduce loyalty points program which can be redeemed by the customers in their next bookings. Amenities such as parking spaces, kids corner, free internet connection can be provided to increase the number of bookings.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The analysis and visualization of hotel booking data have yielded valuable insights that can drive business decisions and strategies for hotel owners and managers. Here are the key conclusions drawn from the project:
#
#
# * City Hotels are preferred by the majority of guests, with approximately 2/3 of total guests choosing them. This preference suggests potential investment opportunities in City Hotels.
# * Most guests originate from Portugal, followed by other European countries. Hotel owners should focus their marketing efforts on these regions.
# * Room type A is the most demanded, followed by types D and E. This insight can help optimize room allocation and pricing.
# * Bed and Breakfast (BB) is the most preferred meal type, but Half Board (HB) and Self Catering (SC) are also popular. Hotel owners can adjust meal plan pricing and offerings accordingly.
# * The year 2016 saw the highest number of bookings, with City Hotels leading in bookings. Hotel owners should consider resource allocation based on yearly trends.
# * Peak booking seasons are from mid-June to August, while off-seasons are from November to February. Dynamic pricing and marketing strategies can be applied accordingly.
# * Travel Agency/Tour Operator channels dominate bookings for both City and Resort Hotels. Exploring collaborations and marketing efforts with these channels is advisable.
# *  About 27.5% of bookings were canceled. Hotel owners should investigate the reasons behind cancellations and improve their booking processes.
# * Identifying top-performing booking agents allows for incentives and strategies to motivate other agents.
# * A small but significant percentage of guests are repeat customers. Loyalty programs and targeted marketing can enhance customer retention.
# * Guests prefer 1-4 days of stay in both City and Resort Hotels, with 7 days also being popular in Resort Hotels. Package offerings can be optimized based on these preferences.
# * 'Direct' and 'TA/TO' channels are significant contributors to Average Daily Rate (ADR). Hotel owners can explore partnerships with these channels.
# * Travel Agency/Tour Operator channels experience both higher bookings and cancellations. Improved communication and strategies with these channels can reduce cancellations.
# * Positive correlations exist between booking count, pricing, total stay, cancellations, and parking spaces. Negative correlation is observed with repeated guests. Pricing may impact customer retention.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
